# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(color_codes=True)

# %%
counts_df = pd.read_csv("counts.csv")
preds_df = pd.read_csv("predictions.csv")

# %%
counts_df.head()
# Out:
#                                            protein   count     gene
# 0                              cytochrome_p450_2d6  111590   CYP2D6
# 1                             cytochrome_p450_2c19  105447  CYP2C19
# 2           macrophage_migration_inhibitory_factor   71565      MIF
# 3                    m_phase_inducer_phosphatase_2   61190   CDC25C
# 4  neuronal_acetylcholine_receptor_subunit_alpha_3   60241   CHRNB4

# %%
preds_df.head()
# Out:
#          protein        id probability
# 0  transthyretin  89670814         svm
# 1  transthyretin   6413728         svm
# 2  transthyretin   6412515         svm
# 3  transthyretin   5666717         svm
# 4  transthyretin   6405079         svm

# %%
len(counts_df), len(preds_df)
# Out:
# (246, 961596)

# %%
plt.figure(figsize=(30, 10))
ax = sns.barplot('protein', 'count', data=counts_df.sample(frac=1))
sns.set(font_scale=3)
ax.set_xlabel('Proteins')
ax.set_ylabel('Hit count')
ax.set_xticks([])
# plt.xticks(rotation=90)
# plt.rc('xtick', labelsize = 16 )
# plt.rc('ytick', labelsize = 16)
# plt.rcParams["axes.labelsize"] = 16
plt.tight_layout()
plt.savefig('chembridge_hits', dpi=300)
plt.show()

# %%
# plt.figure(figsize=(15, 10))
# ax = hit_count.hist()
# ax.set_xlabel('Protein')
# ax.set_ylabel('Count')
# plt.show()
